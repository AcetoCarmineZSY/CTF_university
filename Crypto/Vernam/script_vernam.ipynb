# %%
import struct
import os

# %%
filepath = 'ciphertext0.bin'
binfile = open(filepath,'rb')
size = os.path.getsize(filepath)
cipher0 = []
for i in range(size):
    data = binfile.read(1)
    num = struct.unpack('B',data)
    cipher0.append(num[0])
binfile.close()
len(cipher0)
# Out:
# 1491

# %%
filepath = 'ciphertext1.bin'
binfile = open(filepath,'rb')
size = os.path.getsize(filepath)
cipher1 = []
for i in range(size):
    data = binfile.read(1)
    num = struct.unpack('B',data)
    cipher1.append(num[0])
binfile.close()
len(cipher1)
# Out:
# 1269

# %%
filepath = 'ciphertext2.bin'
binfile = open(filepath,'rb')
size = os.path.getsize(filepath)
cipher2 = []
for i in range(size):
    data = binfile.read(1)
    num = struct.unpack('B',data)
    cipher2.append(num[0])
binfile.close()
len(cipher2)
# Out:
# 1568

# %%
filepath = 'ciphertext3.bin'
binfile = open(filepath,'rb')
size = os.path.getsize(filepath)
cipher3 = []
for i in range(size):
    data = binfile.read(1)
    num = struct.unpack('B',data)
    cipher3.append(num[0])
binfile.close()
len(cipher3)
# Out:
# 1301

# %%
filepath = 'ciphertext4.bin'
binfile = open(filepath,'rb')
size = os.path.getsize(filepath)
cipher4 = []
for i in range(size):
    data = binfile.read(1)
    num = struct.unpack('B',data)
    cipher4.append(num[0])
binfile.close()
len(cipher4)
# Out:
# 1471

# %%
filepath = 'ciphertext5.bin'
binfile = open(filepath,'rb')
size = os.path.getsize(filepath)
cipher5 = []
for i in range(size):
    data = binfile.read(1)
    num = struct.unpack('B',data)
    cipher5.append(num[0])
binfile.close()
len(cipher5)
# Out:
# 690

# %%
filepath = 'ciphertext6.bin'
binfile = open(filepath,'rb')
size = os.path.getsize(filepath)
cipher6 = []
for i in range(size):
    data = binfile.read(1)
    num = struct.unpack('B',data)
    cipher6.append(num[0])
binfile.close()
len(cipher6)
# Out:
# 924

# %%
filepath = 'ciphertext7.bin'
binfile = open(filepath,'rb')
size = os.path.getsize(filepath)
cipher7 = []
for i in range(size):
    data = binfile.read(1)
    num = struct.unpack('B',data)
    cipher7.append(num[0])
binfile.close()
len(cipher7)
# Out:
# 972

# %%
def alphanum(x):
    if chr(x).isalnum():
        return True
    else:
        return False

# %%
i_espace1 = []
for i in range(min(len(cipher0),len(cipher1))):
    if alphanum(cipher0[i]^cipher1[i]):
        i_espace1.append(i)
print(i_espace1)
# m0[i] = 0 propable
# Out:
# [3, 8, 9, 11, 13, 18, 24, 28, 29, 30, 39, 42, 48, 51, 57, 64, 70, 73, 74, 75, 76, 81, 84, 87, 90, 91, 92, 94, 97, 101, 103, 104, 106, 109, 110, 111, 112, 127, 130, 131, 137, 139, 140, 141, 147, 149, 150, 154, 155, 160, 161, 167, 168, 169, 170, 172, 174, 175, 179, 180, 185, 187, 188, 190, 193, 194, 195, 199, 200, 201, 206, 211, 213, 214, 215, 219, 220, 224, 231, 232, 236, 237, 242, 252, 254, 256, 257, 265, 266, 268, 269, 271, 272, 274, 280, 283, 285, 288, 291, 293, 296, 297, 300, 302, 306, 307, 308, 314, 316, 317, 319, 320, 322, 323, 331, 336, 337, 340, 341, 344, 359, 363, 364, 367, 368, 369, 370, 375, 376, 377, 381, 384, 385, 386, 389, 394, 395, 397, 401, 402, 405, 406, 417, 418, 423, 426, 428, 435, 438, 442, 446, 447, 461, 463, 464, 465, 470, 473, 474, 478, 480, 482, 483, 486, 489, 492, 499, 500, 505, 506, 507, 508, 510, 514, 523, 529, 533, 537, 538, 541, 544, 546, 551, 556, 557, 560, 564, 569, 572, 575, 576, 580, 581, 585, 586, 589, 592, 593, 597, 600, 602, 605, 608, 611, 612, 615,
# ...

# %%
i_espace2 = []
for i in range(min(len(cipher0),len(cipher2))):
    if alphanum(cipher0[i]^cipher2[i]):
        i_espace2.append(i)
print(i_espace2)
# Out:
# [7, 9, 13, 14, 23, 24, 31, 33, 35, 36, 39, 42, 45, 48, 51, 58, 70, 71, 72, 73, 79, 81, 87, 88, 89, 90, 94, 101, 103, 108, 109, 111, 114, 115, 116, 120, 123, 129, 130, 134, 139, 141, 147, 148, 149, 152, 155, 158, 160, 167, 169, 170, 172, 174, 179, 185, 188, 193, 194, 208, 209, 214, 215, 218, 222, 232, 237, 238, 247, 248, 252, 267, 269, 272, 274, 275, 280, 284, 285, 293, 294, 297, 301, 302, 307, 308, 309, 316, 317, 319, 322, 323, 324, 328, 331, 335, 336, 342, 343, 344, 348, 351, 356, 359, 363, 366, 368, 369, 374, 375, 376, 381, 385, 395, 397, 399, 401, 402, 404, 406, 407, 421, 423, 426, 427, 428, 432, 440, 441, 442, 444, 446, 450, 455, 456, 464, 465, 468, 470, 478, 479, 484, 486, 489, 490, 492, 494, 500, 501, 505, 512, 515, 518, 520, 523, 524, 534, 535, 536, 538, 539, 542, 544, 550, 551, 555, 558, 560, 562, 563, 564, 565, 568, 570, 571, 576, 579, 581, 585, 586, 591, 592, 595, 597, 601, 602, 605, 607, 608, 612, 615, 616, 622, 624, 626, 629, 631, 632, 636, 638, 641, 647, 648, 649, 657, 6
# ...

# %%
i_espace3 = []
for i in range(min(len(cipher0),len(cipher3))):
    if alphanum(cipher0[i]^cipher3[i]):
        i_espace3.append(i)
print(i_espace3)
# Out:
# [9, 10, 13, 20, 21, 22, 23, 26, 29, 30, 31, 36, 39, 42, 44, 47, 48, 51, 55, 58, 62, 64, 67, 70, 73, 76, 80, 81, 84, 87, 90, 93, 94, 104, 105, 109, 111, 116, 117, 118, 123, 124, 129, 138, 139, 141, 146, 149, 151, 156, 160, 167, 169, 170, 173, 174, 176, 185, 189, 193, 196, 204, 210, 211, 213, 214, 219, 224, 227, 232, 234, 241, 242, 247, 250, 252, 257, 260, 263, 267, 268, 269, 270, 272, 274, 275, 280, 281, 285, 288, 291, 292, 293, 302, 305, 307, 309, 317, 319, 322, 323, 329, 330, 336, 338, 341, 342, 347, 351, 356, 363, 367, 368, 370, 372, 374, 376, 379, 381, 389, 392, 394, 397, 398, 401, 406, 407, 410, 413, 418, 420, 425, 426, 432, 434, 436, 437, 440, 441, 442, 446, 448, 451, 452, 460, 461, 462, 463, 465, 468, 470, 471, 475, 476, 483, 488, 489, 492, 496, 503, 506, 507, 508, 509, 512, 513, 514, 517, 518, 523, 525, 536, 537, 545, 559, 560, 563, 564, 565, 571, 575, 576, 579, 581, 583, 585, 589, 592, 600, 601, 602, 605, 607, 610, 615, 618, 619, 620, 622, 624, 625, 626, 627, 637, 638, 647, 6
# ...

# %%
i_espace4 = []
for i in range(min(len(cipher0),len(cipher4))):
    if alphanum(cipher0[i]^cipher4[i]):
        i_espace4.append(i)
print(i_espace4)
# Out:
# [3, 8, 13, 15, 16, 23, 24, 25, 30, 31, 35, 37, 39, 48, 50, 51, 61, 63, 64, 73, 74, 78, 80, 81, 86, 87, 90, 101, 107, 109, 116, 117, 118, 123, 125, 128, 129, 130, 132, 138, 139, 141, 142, 149, 153, 155, 156, 160, 162, 167, 171, 174, 175, 180, 183, 185, 188, 192, 193, 195, 199, 200, 201, 204, 207, 211, 213, 215, 218, 221, 227, 228, 229, 232, 233, 237, 252, 253, 256, 261, 263, 269, 272, 273, 274, 276, 277, 283, 285, 287, 288, 293, 294, 297, 299, 302, 305, 307, 316, 317, 321, 322, 324, 327, 333, 336, 341, 343, 351, 353, 354, 355, 359, 360, 363, 364, 367, 368, 369, 370, 374, 375, 377, 381, 382, 386, 391, 394, 396, 397, 401, 402, 403, 406, 410, 422, 423, 426, 427, 435, 437, 442, 443, 451, 455, 458, 461, 463, 465, 466, 470, 475, 480, 481, 483, 486, 489, 491, 492, 503, 505, 508, 509, 510, 512, 514, 523, 526, 533, 536, 537, 540, 551, 554, 555, 560, 561, 564, 568, 569, 570, 571, 573, 580, 581, 592, 594, 597, 601, 602, 604, 605, 608, 615, 618, 623, 625, 626, 628, 636, 639, 649, 650, 654, 657, 6
# ...

# %%
i_espace5 = []
for i in range(min(len(cipher0),len(cipher5))):
    if alphanum(cipher0[i]^cipher5[i]):
        i_espace5.append(i)
print(i_espace5)
# Out:
# [7, 9, 13, 16, 19, 24, 29, 30, 35, 39, 42, 47, 48, 50, 51, 59, 65, 71, 73, 79, 80, 81, 87, 90, 91, 92, 94, 95, 101, 104, 108, 110, 111, 116, 118, 123, 124, 126, 130, 131, 137, 139, 140, 141, 144, 152, 155, 160, 161, 170, 174, 176, 177, 180, 183, 184, 185, 187, 188, 193, 194, 197, 200, 203, 204, 210, 213, 215, 216, 224, 231, 232, 239, 246, 247, 252, 254, 256, 257, 261, 266, 268, 272, 274, 277, 280, 285, 289, 293, 295, 296, 297, 302, 304, 305, 307, 308, 316, 317, 322, 325, 328, 333, 336, 341, 345, 347, 351, 355, 361, 363, 364, 368, 369, 374, 376, 377, 378, 379, 381, 384, 386, 392, 394, 395, 397, 401, 404, 406, 407, 411, 418, 419, 423, 426, 429, 430, 432, 435, 438, 441, 442, 443, 446, 447, 450, 455, 458, 465, 468, 470, 473, 480, 483, 486, 489, 491, 492, 494, 500, 501, 503, 504, 505, 507, 508, 512, 513, 514, 517, 518, 523, 529, 530, 538, 544, 545, 551, 556, 560, 561, 563, 564, 568, 570, 571, 573, 576, 585, 586, 592, 594, 601, 602, 612, 620, 622, 625, 627, 629, 630, 642, 650, 656, 657, 65
# ...

# %%
i_espace6 = []
for i in range(min(len(cipher0),len(cipher6))):
    if alphanum(cipher0[i]^cipher6[i]):
        i_espace6.append(i)
print(i_espace6)
# Out:
# [1, 9, 12, 19, 20, 21, 22, 23, 24, 29, 30, 31, 33, 34, 35, 36, 38, 39, 42, 44, 46, 48, 49, 51, 52, 59, 63, 70, 73, 74, 80, 81, 84, 87, 88, 90, 94, 97, 101, 103, 104, 109, 110, 111, 116, 119, 124, 127, 129, 131, 132, 139, 140, 141, 143, 149, 152, 155, 156, 160, 165, 167, 174, 180, 184, 185, 188, 193, 194, 198, 200, 211, 213, 214, 215, 221, 222, 223, 226, 227, 231, 237, 242, 243, 244, 252, 255, 256, 260, 264, 268, 269, 270, 272, 274, 280, 282, 285, 288, 293, 294, 302, 307, 308, 309, 317, 318, 322, 324, 329, 330, 336, 340, 341, 343, 347, 351, 352, 363, 364, 366, 367, 368, 369, 372, 374, 376, 377, 382, 386, 387, 392, 393, 394, 397, 401, 402, 405, 413, 416, 418, 423, 424, 426, 427, 428, 430, 432, 435, 437, 440, 442, 446, 448, 455, 459, 463, 464, 465, 468, 470, 473, 474, 476, 480, 483, 484, 485, 489, 492, 494, 498, 500, 502, 504, 505, 507, 508, 511, 514, 518, 523, 525, 529, 530, 531, 532, 533, 534, 537, 538, 543, 544, 546, 550, 551, 555, 564, 568, 569, 571, 574, 576, 579, 581, 583, 585, 59
# ...

# %%
i_espace7 = []
for i in range(min(len(cipher0),len(cipher7))):
    if alphanum(cipher0[i]^cipher7[i]):
        i_espace7.append(i)
print(i_espace7)
# Out:
# [1, 9, 10, 15, 22, 24, 25, 29, 30, 38, 39, 42, 43, 47, 48, 50, 51, 58, 61, 63, 73, 74, 76, 81, 83, 87, 90, 97, 101, 104, 105, 109, 111, 123, 124, 129, 132, 137, 141, 148, 149, 151, 155, 160, 162, 166, 167, 169, 170, 174, 177, 180, 186, 188, 190, 193, 199, 200, 201, 203, 209, 213, 214, 215, 219, 223, 227, 228, 231, 232, 237, 239, 240, 242, 247, 252, 257, 259, 269, 272, 274, 277, 283, 285, 288, 289, 297, 302, 304, 307, 312, 315, 317, 322, 324, 325, 333, 336, 341, 344, 347, 349, 350, 351, 352, 354, 356, 360, 363, 365, 368, 369, 370, 373, 374, 375, 376, 377, 380, 385, 386, 394, 396, 397, 401, 404, 406, 412, 416, 418, 423, 426, 427, 431, 432, 435, 437, 442, 446, 448, 449, 453, 463, 465, 466, 478, 480, 487, 489, 492, 494, 499, 500, 504, 508, 509, 512, 514, 521, 523, 530, 537, 540, 544, 551, 552, 553, 555, 560, 563, 565, 568, 571, 572, 576, 578, 581, 585, 590, 592, 593, 596, 597, 602, 605, 606, 611, 612, 614, 615, 622, 623, 625, 627, 631, 635, 638, 639, 646, 647, 649, 650, 657, 658, 659, 66
# ...

# %%
# counteur
dict = {}
for key in i_espace1+i_espace2+i_espace3+i_espace4+i_espace5+i_espace6+i_espace7:
    dict[key] = dict.get(key,0)+1
m0i_espace = []
for key in dict:    
    if (dict[key]>4):
        m0i_espace.append(key)
print(m0i_espace)
# Out:
# [9, 13, 24, 29, 30, 39, 42, 48, 51, 73, 81, 87, 90, 94, 101, 104, 109, 111, 139, 141, 149, 155, 160, 167, 170, 174, 180, 185, 188, 193, 200, 213, 214, 215, 232, 237, 252, 269, 272, 274, 280, 285, 288, 293, 297, 302, 307, 317, 322, 336, 341, 363, 368, 369, 376, 377, 381, 386, 394, 397, 401, 406, 418, 423, 426, 435, 442, 446, 463, 465, 470, 480, 483, 489, 492, 500, 505, 508, 514, 523, 537, 544, 551, 560, 564, 576, 581, 585, 592, 597, 602, 605, 615, 622, 627, 647, 657, 658, 662, 671, 676, 681, 690, 694, 696, 731, 735, 749, 751, 757, 779, 798, 802, 806, 818, 833, 838, 842, 854, 866, 876, 880, 889, 896, 901, 911, 918, 941, 953, 116, 123, 129, 351, 374, 432, 512, 568, 571, 713, 862, 625]

# %%
# cle
k = []
#length
for j in range(max(m0i_espace)+1):
    k.append('*')

for i in range(max(m0i_espace)+1):
    if (i in m0i_espace):
        k[i]=(32^cipher0[i])  # [m0 XOR c0]_i = k_i
print(k)
# Out:
# ['*', '*', '*', '*', '*', '*', '*', '*', '*', 30, '*', '*', '*', 206, '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', 198, '*', '*', '*', '*', 196, 51, '*', '*', '*', '*', '*', '*', '*', '*', 38, '*', '*', 156, '*', '*', '*', '*', '*', 181, '*', '*', 42, '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', 144, '*', '*', '*', '*', '*', '*', '*', 115, '*', '*', '*', '*', '*', 145, '*', '*', 193, '*', '*', '*', 52, '*', '*', '*', '*', '*', '*', 200, '*', '*', 89, '*', '*', '*', '*', 4, '*', 134, '*', '*', '*', '*', 205, '*', '*', '*', '*', '*', '*', 212, '*', '*', '*', '*', '*', 182, '*', '*', '*', '*', '*', '*', '*', '*', '*', 250, '*', 97, '*', '*', '*', '*', '*', '*', '*', 18, '*', '*', '*', '*', '*', 93, '*', '*', '*', '*', 44, '*', '*', '*', '*', '*', '*', 222, '*', '*', 238, '*', '*', '*', 56, '*', '*', '*', '*', '*', 218, '*', '*', '*', '*', 84, '*', '*', 202, '*', '*', '*', '*', 101, '*', '*', '*', '*', '*', '*', 224, '*', '
# ...

# %%
i_espace10 = []
for i in range(min(len(cipher1),len(cipher0))):
    if alphanum(cipher1[i]^cipher0[i]):
        i_espace10.append(i)

i_espace12 = []
for i in range(min(len(cipher2),len(cipher1))):
    if alphanum(cipher2[i]^cipher1[i]):
        i_espace12.append(i)

i_espace13 = []
for i in range(min(len(cipher1),len(cipher3))):
    if alphanum(cipher1[i]^cipher3[i]):
        i_espace13.append(i)

i_espace14 = []
for i in range(min(len(cipher1),len(cipher4))):
    if alphanum(cipher1[i]^cipher4[i]):
        i_espace14.append(i)

i_espace15 = []
for i in range(min(len(cipher1),len(cipher5))):
    if alphanum(cipher1[i]^cipher5[i]):
        i_espace15.append(i)

i_espace16 = []
for i in range(min(len(cipher1),len(cipher6))):
    if alphanum(cipher1[i]^cipher6[i]):
        i_espace16.append(i)

i_espace17 = []
for i in range(min(len(cipher1),len(cipher7))):
    if alphanum(cipher1[i]^cipher7[i]):
        i_espace17.append(i)

# counteur
dict1 = {}
for key in i_espace10 + i_espace12 + i_espace13 + i_espace14 + i_espace15 + i_espace16 + i_espace17:
    dict1[key] = dict1.get(key,0)+1
m1i_espace = []
for key in dict1:    
    if (dict1[key]>4):
        m1i_espace.append(key)
print(m1i_espace)
# Out:
# [3, 8, 11, 18, 28, 57, 64, 75, 76, 84, 92, 97, 103, 106, 110, 127, 137, 140, 147, 150, 154, 161, 168, 172, 175, 179, 187, 190, 199, 206, 211, 219, 220, 224, 236, 254, 265, 266, 271, 283, 291, 300, 306, 314, 319, 320, 331, 337, 340, 359, 384, 389, 395, 402, 405, 417, 428, 438, 447, 461, 464, 473, 478, 482, 505, 510, 529, 533, 538, 541, 546, 556, 569, 572, 575, 580, 589, 593, 600, 611, 618, 630, 636, 642, 648, 659, 677, 678, 679, 686, 692, 709, 724, 733, 746, 752, 763, 769, 777, 796, 809, 815, 819, 824, 831, 834, 839, 847, 852, 868, 872, 877, 888, 891, 894, 902, 910, 913, 932, 957, 965, 17, 19, 77, 116, 123, 129, 351, 356, 374, 432, 498, 563, 713, 790, 858, 625]

# %%
#key length
if max(m1i_espace)>len(k):
    for i in range(max(m1i_espace)-len(k)+1):
        k.append('*')
        
for i in range(max(m1i_espace)+1):
    if (i in m1i_espace)&(k[i]=='*'):
        k[i]=(32^cipher1[i])  # [m1 XOR c1]_i = k_i
    elif(i in m1i_espace)&(k[i]!='*')& (k[i] != 32^cipher1[i]):
        print("conflict number:")
        print(i)
        print(k[i])
        print((32^cipher1[i]))
    else:
        pass
print(k)
# Out:
# conflict number:
# 123
# 212
# 214
# conflict number:
# 374
# 49
# 57
# conflict number:
# 505
# 184
# 219
# ...

# %%
i_espace20 = []
for i in range(min(len(cipher2),len(cipher0))):
    if alphanum(cipher2[i]^cipher0[i]):
        i_espace20.append(i)

i_espace21 = []
for i in range(min(len(cipher2),len(cipher1))):
    if alphanum(cipher2[i]^cipher1[i]):
        i_espace21.append(i)

i_espace23 = []
for i in range(min(len(cipher2),len(cipher3))):
    if alphanum(cipher2[i]^cipher3[i]):
        i_espace23.append(i)

i_espace24 = []
for i in range(min(len(cipher2),len(cipher4))):
    if alphanum(cipher2[i]^cipher4[i]):
        i_espace24.append(i)

i_espace25 = []
for i in range(min(len(cipher2),len(cipher5))):
    if alphanum(cipher2[i]^cipher5[i]):
        i_espace25.append(i)

i_espace26 = []
for i in range(min(len(cipher2),len(cipher6))):
    if alphanum(cipher2[i]^cipher6[i]):
        i_espace26.append(i)

i_espace27 = []
for i in range(min(len(cipher2),len(cipher7))):
    if alphanum(cipher2[i]^cipher7[i]):
        i_espace27.append(i)

# counteur
dict2 = {}
for key in i_espace20 + i_espace21 + i_espace23 + i_espace24 + i_espace25 + i_espace26 + i_espace27:
    dict2[key] = dict2.get(key,0)+1
m2i_espace = []
for key in dict2:    
    if (dict2[key]>4):
        m2i_espace.append(key)
print(m2i_espace)
# Out:
# [7, 14, 33, 36, 45, 71, 72, 79, 88, 89, 103, 108, 114, 115, 116, 120, 134, 147, 148, 152, 158, 172, 179, 208, 209, 218, 222, 238, 248, 267, 275, 284, 294, 301, 309, 319, 328, 331, 335, 348, 359, 366, 385, 395, 399, 404, 407, 421, 440, 444, 456, 464, 478, 479, 490, 501, 520, 524, 535, 539, 542, 550, 558, 562, 570, 579, 586, 591, 595, 601, 616, 624, 631, 632, 636, 641, 648, 660, 669, 678, 682, 687, 695, 702, 705, 708, 711, 715, 723, 738, 765, 781, 787, 791, 792, 794, 820, 825, 827, 828, 832, 839, 856, 860, 865, 873, 878, 881, 885, 890, 898, 900, 909, 915, 917, 927, 934, 962, 22, 30, 180, 201, 213, 288, 320, 327, 341, 377, 394, 418, 435, 462, 463, 508, 514, 628, 671, 757, 798, 818, 842, 911, 916, 482]

# %%
if max(m2i_espace)>len(k):
    for i in range(max(m2i_espace)-len(k)+1):
        k.append('*')
        
for i in range(max(m2i_espace)+1):
    if (i in m2i_espace)&(k[i]=='*'):
        k[i]=(32^cipher2[i])  # [m2 XOR c2]_i = k_i
        
    elif(i in m2i_espace) & (k[i] != '*') & (k[i] != 32^cipher2[i]):
        print("conflict number:")
        print(i)
        print(k[i])
        print((32^cipher2[i]))
    else:
        pass
print(k)
# Out:
# conflict number:
# 30
# 51
# 8
# conflict number:
# 103
# 192
# 204
# conflict number:
# 116
# 205
# 175
# conflict number:
# 147
# 62
# 50
# conflict number:
# 172
# 31
# 53
# conflict number:
# 179
# 5
# 9
# conflict number:
# 319
# 228
# 232
# conflict number:
# 320
# 144
# 224
# conflict number:
# 377
# 193
# 235
# conflict number:
# 394
# 40
# 36
# conflict number:
# 464
# 227
# 147
# conflict number:
# 482
# 196
# 221
# conflict number:
# 648
# 157
# 145
# ...

# %%
i_espace30 = []
for i in range(min(len(cipher3),len(cipher0))):
    if alphanum(cipher3[i]^cipher0[i]):
        i_espace30.append(i)

i_espace31 = []
for i in range(min(len(cipher3),len(cipher1))):
    if alphanum(cipher3[i]^cipher1[i]):
        i_espace31.append(i)

i_espace32 = []
for i in range(min(len(cipher3),len(cipher2))):
    if alphanum(cipher3[i]^cipher2[i]):
        i_espace32.append(i)

i_espace34 = []
for i in range(min(len(cipher3),len(cipher4))):
    if alphanum(cipher3[i]^cipher4[i]):
        i_espace34.append(i)

i_espace35 = []
for i in range(min(len(cipher3),len(cipher5))):
    if alphanum(cipher3[i]^cipher5[i]):
        i_espace35.append(i)

i_espace36 = []
for i in range(min(len(cipher3),len(cipher6))):
    if alphanum(cipher3[i]^cipher6[i]):
        i_espace36.append(i)

i_espace37 = []
for i in range(min(len(cipher3),len(cipher7))):
    if alphanum(cipher3[i]^cipher7[i]):
        i_espace37.append(i)


# counteur
dict3 = {}
for key in i_espace30 + i_espace31 + i_espace32 + i_espace34 + i_espace35 + i_espace36 + i_espace37:
    dict3[key] = dict3.get(key,0)+1
    
m3i_espace = []
for key in dict3:    
    if (dict3[key]>4):
        m3i_espace.append(key)
print(m3i_espace)
# Out:
# [10, 21, 26, 36, 44, 47, 48, 55, 62, 64, 67, 76, 84, 93, 105, 117, 118, 138, 146, 151, 173, 176, 196, 204, 210, 214, 219, 224, 234, 241, 242, 250, 260, 263, 267, 270, 275, 281, 291, 309, 319, 329, 338, 342, 368, 372, 379, 389, 392, 398, 407, 410, 413, 420, 425, 434, 436, 437, 440, 448, 451, 452, 460, 461, 471, 475, 488, 496, 503, 509, 513, 517, 525, 536, 537, 559, 575, 579, 583, 589, 600, 601, 607, 610, 619, 620, 624, 637, 652, 661, 664, 667, 673, 691, 707, 729, 737, 743, 748, 755, 758, 760, 768, 795, 800, 804, 815, 835, 843, 852, 856, 861, 870, 874, 885, 892, 893, 897, 921, 928, 955, 24, 101, 155, 180, 188, 200, 215, 237, 316, 375, 386, 423, 480, 499, 544, 551, 671, 676, 681, 833, 918, 568]

# %%
if max(m3i_espace)>len(k):
    for i in range(max(m3i_espace)-len(k)+1):
        k.append('*')
        
for i in range(max(m3i_espace)+1):
    if (i in m3i_espace)&(k[i]=='*'):
        k[i]=(32^cipher3[i])  # [m3 XOR c3]_i = k_i
        
    elif(i in m3i_espace) & (k[i] != '*') & (k[i] != 32^cipher3[i]):
        print("conflict number:")
        print(i)
        print(k[i])
        print((32^cipher3[i]))
    else:
        pass
print(k)
# Out:
# conflict number:
# 24
# 198
# 236
# conflict number:
# 36
# 54
# 85
# conflict number:
# 48
# 181
# 194
# conflict number:
# 64
# 57
# 48
# conflict number:
# 76
# 33
# 11
# conflict number:
# 155
# 93
# 119
# conflict number:
# 214
# 167
# 200
# conflict number:
# 219
# 245
# 249
# conflict number:
# 224
# 101
# 79
# conflict number:
# 237
# 11
# 33
# conflict number:
# 319
# 228
# 232
# conflict number:
# 368
# 203
# 251
# conflict number:
# 440
# 167
# 141
# conflict number:
# 537
# 46
# 89
# conflict number:
# 589
# 250
# 247
# conflict number:
# 601
# 143
# 234
# conflict number:
# 671
# 145
# 187
# conflict number:
# 815
# 171
# 129
# conflict number:
# 833
# 94
# 89
# conflict number:
# 885
# 97
# 75
# ...

# %%
i_espace40 = []
for i in range(min(len(cipher4),len(cipher0))):
    if alphanum(cipher4[i]^cipher0[i]):
        i_espace40.append(i)

i_espace41 = []
for i in range(min(len(cipher4),len(cipher1))):
    if alphanum(cipher4[i]^cipher1[i]):
        i_espace41.append(i)

i_espace42 = []
for i in range(min(len(cipher4),len(cipher2))):
    if alphanum(cipher4[i]^cipher2[i]):
        i_espace42.append(i)
        
i_espace43 = []
for i in range(min(len(cipher4),len(cipher3))):
    if alphanum(cipher4[i]^cipher3[i]):
        i_espace43.append(i)

i_espace45 = []
for i in range(min(len(cipher4),len(cipher5))):
    if alphanum(cipher4[i]^cipher5[i]):
        i_espace45.append(i)

i_espace46 = []
for i in range(min(len(cipher4),len(cipher6))):
    if alphanum(cipher4[i]^cipher6[i]):
        i_espace46.append(i)

i_espace47 = []
for i in range(min(len(cipher4),len(cipher7))):
    if alphanum(cipher4[i]^cipher7[i]):
        i_espace47.append(i)

# counteur
dict4 = {}
for key in i_espace40 + i_espace41 + i_espace42 + i_espace43 + i_espace45 + i_espace46 + i_espace47:
    dict4[key] = dict4.get(key,0)+1
m4i_espace = []
for key in dict4:    
    if (dict4[key]>4):
        m4i_espace.append(key)
print(m4i_espace)
# Out:
# [3, 8, 16, 25, 37, 50, 61, 64, 78, 86, 107, 117, 118, 125, 128, 132, 138, 142, 153, 156, 162, 171, 175, 183, 192, 195, 199, 204, 207, 211, 218, 221, 228, 229, 233, 253, 261, 263, 273, 277, 283, 287, 294, 299, 321, 327, 333, 343, 353, 354, 355, 359, 364, 370, 382, 391, 396, 402, 403, 410, 422, 437, 451, 458, 461, 466, 475, 481, 491, 503, 510, 526, 533, 536, 540, 554, 561, 570, 573, 580, 594, 601, 604, 618, 623, 636, 639, 654, 661, 668, 672, 680, 683, 692, 705, 722, 738, 748, 756, 765, 769, 780, 783, 787, 791, 795, 799, 807, 816, 823, 828, 829, 835, 843, 855, 867, 877, 909, 919, 920, 924, 949, 9, 22, 29, 42, 60, 94, 104, 111, 280, 418, 441, 446, 544, 576, 585, 622, 627, 647, 731, 751, 896, 432]

# %%
if max(m4i_espace)>len(k):
    for i in range(max(m4i_espace)-len(k)+1):
        k.append('*')

for i in range(max(m4i_espace)+1):
    if (i in m4i_espace)&(k[i]=='*'):
        k[i]=(32^cipher4[i])  # [m2 XOR c2]_i = k_i
        
    elif(i in m4i_espace) & (k[i] != '*') & (k[i] != 32^cipher4[i]):
        print("conflict number:")
        print(i)
        print(k[i])
        print((32^cipher4[i]))
    else:
        pass
print(k)
# Out:
# conflict number:
# 9
# 30
# 22
# conflict number:
# 64
# 57
# 44
# conflict number:
# 94
# 52
# 30
# conflict number:
# 117
# 72
# 70
# conflict number:
# 118
# 129
# 242
# conflict number:
# 204
# 127
# 85
# conflict number:
# 263
# 167
# 141
# conflict number:
# 327
# 53
# 57
# conflict number:
# 402
# 15
# 3
# conflict number:
# 437
# 65
# 53
# conflict number:
# 446
# 197
# 239
# conflict number:
# 451
# 7
# 45
# conflict number:
# 533
# 54
# 49
# conflict number:
# 570
# 73
# 68
# conflict number:
# 647
# 53
# 31
# conflict number:
# 791
# 206
# 234
# conflict number:
# 828
# 214
# 218
# conflict number:
# 877
# 113
# 91
# conflict number:
# 909
# 82
# 85
# ...

# %%
i_espace50 = []
for i in range(min(len(cipher5),len(cipher0))):
    if alphanum(cipher5[i]^cipher0[i]):
        i_espace50.append(i)

i_espace51 = []
for i in range(min(len(cipher5),len(cipher1))):
    if alphanum(cipher5[i]^cipher1[i]):
        i_espace51.append(i)
        
i_espace52 = []
for i in range(min(len(cipher5),len(cipher2))):
    if alphanum(cipher5[i]^cipher2[i]):
        i_espace52.append(i)

i_espace53 = []
for i in range(min(len(cipher5),len(cipher3))):
    if alphanum(cipher5[i]^cipher3[i]):
        i_espace53.append(i)

i_espace54 = []
for i in range(min(len(cipher5),len(cipher4))):
    if alphanum(cipher5[i]^cipher4[i]):
        i_espace54.append(i)

i_espace56 = []
for i in range(min(len(cipher5),len(cipher6))):
    if alphanum(cipher5[i]^cipher6[i]):
        i_espace56.append(i)

i_espace57 = []
for i in range(min(len(cipher5),len(cipher7))):
    if alphanum(cipher5[i]^cipher7[i]):
        i_espace57.append(i)


# counteur
dict5 = {}
for key in i_espace50 + i_espace51 + i_espace52 + i_espace53 + i_espace54 + i_espace56 + i_espace57:
    dict5[key] = dict5.get(key,0)+1
m5i_espace = []
for key in dict5:    
    if (dict5[key]>4):
        m5i_espace.append(key)
print(m5i_espace)
# Out:
# [16, 19, 47, 50, 59, 65, 71, 92, 95, 108, 110, 118, 126, 131, 137, 140, 144, 161, 176, 177, 183, 184, 187, 197, 203, 204, 210, 216, 224, 239, 246, 254, 261, 266, 277, 289, 295, 325, 328, 333, 345, 355, 361, 379, 384, 392, 404, 407, 411, 419, 429, 430, 438, 447, 450, 458, 473, 491, 505, 513, 517, 518, 530, 545, 556, 561, 570, 573, 586, 594, 601, 620, 630, 642, 656, 659, 663, 674, 677, 689, 78, 109, 149, 167, 269, 375, 463, 537, 581, 597, 605, 606, 615, 638, 647, 129]

# %%
for i in range(max(m5i_espace)+1):
    if (i in m5i_espace)&(k[i]=='*'):
        k[i]=(32^cipher5[i])  # [m2 XOR c2]_i = k_i
        
    elif(i in m5i_espace) & (k[i] != '*') & (k[i] != 32^cipher5[i]):
        print("conflict number:")
        print(i)
        print(k[i])
        print((32^cipher5[i]))
    else:
        pass
print(k)
# Out:
# conflict number:
# 19
# 9
# 35
# conflict number:
# 71
# 245
# 249
# conflict number:
# 78
# 135
# 139
# conflict number:
# 108
# 245
# 251
# conflict number:
# 110
# 37
# 85
# conflict number:
# 167
# 222
# 244
# conflict number:
# 176
# 151
# 155
# conflict number:
# 183
# 47
# 35
# conflict number:
# 261
# 243
# 244
# conflict number:
# 333
# 33
# 11
# conflict number:
# 355
# 54
# 28
# conflict number:
# 384
# 163
# 173
# conflict number:
# 438
# 152
# 178
# conflict number:
# 505
# 184
# 219
# conflict number:
# 537
# 46
# 4
# conflict number:
# 570
# 73
# 68
# conflict number:
# 573
# 212
# 254
# conflict number:
# 620
# 172
# 219
# conflict number:
# 630
# 26
# 121
# conflict number:
# 659
# 46
# 4
# conflict number:
# 677
# 77
# 105
# ...

# %%
i_espace60 = []
for i in range(min(len(cipher6),len(cipher0))):
    if alphanum(cipher6[i]^cipher0[i]):
        i_espace60.append(i)

i_espace61 = []
for i in range(min(len(cipher6),len(cipher1))):
    if alphanum(cipher6[i]^cipher1[i]):
        i_espace61.append(i)
        
i_espace62 = []
for i in range(min(len(cipher6),len(cipher2))):
    if alphanum(cipher6[i]^cipher2[i]):
        i_espace62.append(i)

i_espace63 = []
for i in range(min(len(cipher6),len(cipher3))):
    if alphanum(cipher6[i]^cipher3[i]):
        i_espace63.append(i)

i_espace64 = []
for i in range(min(len(cipher6),len(cipher4))):
    if alphanum(cipher6[i]^cipher4[i]):
        i_espace64.append(i)
        
i_espace65 = []
for i in range(min(len(cipher6),len(cipher5))):
    if alphanum(cipher6[i]^cipher5[i]):
        i_espace65.append(i)

i_espace67 = []
for i in range(min(len(cipher6),len(cipher7))):
    if alphanum(cipher6[i]^cipher7[i]):
        i_espace67.append(i)

# counteur
dict6 = {}
for key in i_espace60 + i_espace61 + i_espace62 + i_espace63 + i_espace64 + i_espace65 + i_espace67:
    dict6[key] = dict6.get(key,0)+1
m6i_espace = []
for key in dict6:    
    if (dict6[key]>4):
        m6i_espace.append(key)
print(m6i_espace)
# Out:
# [1, 12, 20, 21, 33, 34, 36, 38, 44, 46, 49, 52, 84, 88, 97, 103, 110, 119, 127, 131, 132, 140, 143, 152, 156, 165, 184, 198, 211, 222, 223, 226, 242, 243, 244, 255, 260, 264, 270, 282, 294, 309, 329, 330, 340, 343, 352, 366, 368, 372, 387, 392, 393, 405, 413, 416, 424, 428, 430, 437, 440, 448, 459, 464, 473, 474, 476, 484, 485, 505, 511, 518, 525, 530, 531, 533, 534, 538, 543, 546, 550, 569, 574, 579, 583, 599, 600, 613, 642, 651, 656, 667, 673, 680, 688, 702, 711, 718, 721, 730, 739, 756, 762, 780, 781, 792, 804, 807, 820, 831, 837, 844, 845, 855, 871, 890, 914, 13, 130, 170, 232, 297, 381, 406, 560, 592, 638, 789, 875, 563]

# %%
for i in range(max(m6i_espace)+1):
    if (i in m6i_espace)&(k[i]=='*'):
        k[i]=(32^cipher6[i])  # [m2 XOR c2]_i = k_i
        
    elif(i in m6i_espace) & (k[i] != '*') & (k[i] != 32^cipher6[i]):
        print("conflict number:")
        print(i)
        print(k[i])
        print((32^cipher6[i]))
    else:
        pass
print(k)
# Out:
# conflict number:
# 13
# 206
# 198
# conflict number:
# 21
# 71
# 111
# conflict number:
# 33
# 238
# 236
# conflict number:
# 36
# 54
# 87
# conflict number:
# 44
# 183
# 181
# conflict number:
# 88
# 133
# 137
# conflict number:
# 131
# 169
# 167
# conflict number:
# 132
# 84
# 126
# conflict number:
# 140
# 40
# 2
# conflict number:
# 211
# 149
# 191
# conflict number:
# 232
# 190
# 188
# conflict number:
# 242
# 127
# 71
# conflict number:
# 366
# 123
# 121
# conflict number:
# 368
# 203
# 251
# conflict number:
# 405
# 72
# 74
# conflict number:
# 428
# 20
# 22
# conflict number:
# 437
# 65
# 53
# conflict number:
# 440
# 167
# 141
# conflict number:
# 448
# 140
# 142
# conflict number:
# 473
# 198
# 202
# conflict number:
# 505
# 184
# 219
# conflict number:
# 518
# 123
# 66
# conflict number:
# 525
# 174
# 132
# conflict number:
# 530
# 65
# 67
# conflict number:
# 533
# 54
# 43
# conflict number:
# 583
# 216
# 242
# conflict number:
# 656
# 151
# 189
# conflict number:
# 673
# ...

# %%
i_espace70 = []
for i in range(min(len(cipher7),len(cipher0))):
    if alphanum(cipher7[i]^cipher0[i]):
        i_espace60.append(i)

i_espace71 = []
for i in range(min(len(cipher7),len(cipher1))):
    if alphanum(cipher7[i]^cipher1[i]):
        i_espace71.append(i)
        
i_espace72 = []
for i in range(min(len(cipher7),len(cipher2))):
    if alphanum(cipher7[i]^cipher2[i]):
        i_espace72.append(i)

i_espace73 = []
for i in range(min(len(cipher7),len(cipher3))):
    if alphanum(cipher7[i]^cipher3[i]):
        i_espace73.append(i)

i_espace74 = []
for i in range(min(len(cipher7),len(cipher4))):
    if alphanum(cipher7[i]^cipher4[i]):
        i_espace74.append(i)
        
i_espace75 = []
for i in range(min(len(cipher7),len(cipher5))):
    if alphanum(cipher7[i]^cipher5[i]):
        i_espace75.append(i)

i_espace76 = []
for i in range(min(len(cipher6),len(cipher7))):
    if alphanum(cipher6[i]^cipher7[i]):
        i_espace76.append(i)

# counteur
dict7 = {}
for key in i_espace70 + i_espace71 + i_espace72 + i_espace73 + i_espace74 + i_espace75 + i_espace76:
    dict7[key] = dict7.get(key,0)+1
m7i_espace = []
for key in dict7:    
    if (dict7[key]>4):
        m7i_espace.append(key)
print(m7i_espace)
# Out:
# [1, 10, 13, 15, 38, 43, 61, 80, 83, 94, 105, 139, 148, 151, 162, 166, 177, 186, 203, 214, 223, 240, 259, 268, 280, 289, 293, 304, 312, 313, 325, 349, 350, 360, 365, 373, 381, 382, 396, 412, 416, 431, 449, 453, 466, 470, 483, 487, 507, 521, 553, 564, 578, 590, 596, 606, 614, 623, 631, 635, 639, 646, 666, 682, 685, 732, 741, 776, 788, 797, 814, 869, 883, 889, 116, 185, 190, 498, 572, 593, 611]

# %%
for i in range(max(m7i_espace)+1):
    if (i in m7i_espace)&(k[i]=='*'):
        k[i]=(32^cipher7[i])  # [m2 XOR c2]_i = k_i
        
    elif(i in m7i_espace) & (k[i] != '*') & (k[i] != 32^cipher7[i]):
        print("conflict number:")
        print(i)
        print(k[i])
        print((32^cipher7[i]))
    else:
        pass
print(k)
# Out:
# conflict number:
# 61
# 163
# 137
# conflict number:
# 94
# 52
# 30
# conflict number:
# 139
# 250
# 208
# conflict number:
# 185
# 84
# 88
# conflict number:
# 203
# 243
# 255
# conflict number:
# 214
# 167
# 196
# conflict number:
# 223
# 41
# 93
# conflict number:
# 325
# 182
# 156
# conflict number:
# 382
# 0
# 116
# conflict number:
# 593
# 51
# 25
# conflict number:
# 606
# 253
# 137
# conflict number:
# 623
# 14
# 125
# conflict number:
# 631
# 46
# 32
# ...

# %%
m0=[]
for m in range(len(cipher0)):
    m0.append(' ')
for i in range(len(k)):
    if(k[i]!='*'):
        m0[i] = chr(cipher0[i]^k[i])

for p in m0:
    print(p,end="")
# Out:
# Placement new operator:
#
# Line 1 creates an array of sizeof(Fred) bytes of memory, which is b(fenough to hold aeFrkd =bject.aLin1 2ocreate4 a 5ointer pla0e 2hat p=ints
# th xhe #irst by e of thi6 m*mor< (exper/enc d C pr;gr5mmers'will =ote
# thatAthis,step %as%unnecessary, it'6 thireton?y t* make 0he c;de mo7e
# red(). The 'hih poin:er i& the F~ed con tructorgwil) bb
# qualeto p$ace} TheXretu7ned Zo-nt<r f <iul ther&fore #e eq!al t# p}ace.
#
# ADICE: D;n't usetthis Zl-cementint5 sp#tKxeunq$7s ro!,have  o. @4- iy olys%he+ {or r|'lly c2re {da  fn b/ctyks ZQac t ! `\ziy'l)r
# 8.caa,*n i/pmefo6y  lo& ex|Gp`g3 $xei woQ B>dwlrO h8  a *    ye a pudIX {ik r? e"ic`   nNSyEQ za<x0t`ea ave h Ct c% oajlczta  t;      ort oda   n.
#
# JAAGR:
# ou srh & ks   so*  rOO onfkni` ty t-at td  $cijy~   op 5ao}kto _ h >lacement Dea oqeaa8 r Zogntu tcbc rl     hf `emm|y +hag e  be  nsud      U      b    rxbg{   nh b

# %%
m1=[]
for m in range(len(cipher1)):
    m1.append(' ')
for i in range(len(k)):
    if(k[i]!='*'):
        m1[i] = chr(cipher1[i]^k[i])

for p in m1:
    print(p,end="")
# Out:
# The flag is yours.
#
# The code is ghyvcrfgkihjsvcrfvrkuimoj
#
# Congratulations.
#
# Cyclura nubila,a`zso known as the ubon ;guana,ais 5 s?ecies (f l,zard of
# th6 i!uana 4amily.'Ix isethe lar3est of t-e esteIndian 4ockeiguana', ;ne
# of'the m<st endanered,group! oc lizards. This h rbizor;ussspe&ies wi0h
# re0 eyesi a thick 1ail  &nd sp,ked jowls is on6 ofethe larg steliza<dssinDthe CaXibbe2n.;The C;ban !guana es dist!ibuted 3hro0ghhu theerock1
# so&ther< coa6tal Kr!asyof m*iwland C6ba an% itstsurr#unuing isle1s withta
# feraltpopulKt%on thr vx,g f# cs)a P #uere'  Puer o R|$'. D^ s 2>soefmuid
# v( the aymnb skansef kttFX Cmn !nt oyw3nhBr5", b- re  pse{a6aze s!bspxIiiq?o0suus   FmK)s juKrdy hei5    th i ec hns `fr n? e't l   i^s Axna$mdekes  Vubhn { o-odjlls tA  as      e `Osrr   the Muma* ig&anaokt7  w   s / s BS e bkxhe  or +ear | i7gl} k    fa&tu kAl^C xg& the wild pypumagi#  iY gn bec`+le k     b ok ppkda+io} n  fi   }nj     aR      s   l|gx v   mc

# %%
m2=[]
for m in range(len(cipher2)):
    m2.append(' ')
for i in range(len(k)):
    if(k[i]!='*'):
        m2[i] = chr(cipher2[i]^k[i])

for p in m2:
    print(p,end="")
# Out:
# Shakira Isabel Mebarak Ripoll
#
# is a Colombian singer-songwriter, dancer, record producer, ch.ssographer,
# and mo!el  B=rn andarai'edoin Bar5anq0illa, she 1eg'n per4orming'ib
# sc-ool, de9onstrati+g ati+, Arabi%, a+d rocktan0 roll'influ6nces andkbellu danc;ng%abilities. Shaki7a rile5se7 he7 firstdstud=o alb0ms, MagiaOand,P"ligroi in the early 1j90si failingetoeatta'n 0om#ercial
# succ6ss
# howe8er, ;he rosi to pr<minencegin 	atnnOAmer,ca w!th ;er m3jor-)abel d!bu-, Pi.s9Descal9os (1x96),tand $er1fourth a)bum, D;nde Est5n los L-dronesi( {98 c
#  S-akt3% eet1~ed th1 Enr+!sh Fagu25e (apkbt n/th he! fiixhtakbu,e/au7fry nerc (r0 J  S&shle5% s|+"le,arWhnn!vkr herx\e~ 3 1ucfmk Ke )st sOll0 g s.     '   0 2' _e} u c| s' wd   oFdCBihdr{ytgey r5siqth n* sfvlnz<   b&      acdE Hr    Vol  > %nd ral2Fdx3 iu   Vo*  2  00 +  x e la1ter c  #dige;   wke! hf. bOX  s+lling sonM yf uhv ~ st ckntsry b Hiy      t Aie   S7akz m   i  tt b     nH      j   S{q+Wz    5 r

# %%
m3=[]
for m in range(len(cipher3)):
    m3.append(' ')
for i in range(len(k)):
    if(k[i]!='*'):
        m3[i] = chr(cipher3[i]^k[i])

for p in m3:
    print(p,end="")
# Out:
# Republique francaise
#
# is a soPereig  0ount+y in We?tern Europe that in+lud1s s veral o"erseas
# >egions an! t+rri1orges| Metro1oli anoFrancegext nds from t;e
# edite ranean'Sia t* the En3lish Cha+ne# an! the No4th ea, an0 f&om thb
# Rhin6 to the  tlanxic Oc7an+ It is one of on)y tdre1 c<unt7ies (w-th
# M;roccoeand Spainl to,h&ve bo1h Atlantic and edi1erraneaneco$stli es}
# D;e to i^s sh2pe7 it i= oft-n refe~red tosin Fren$h a6 l H
# xago+e ("he
# exag=n").O
# By Kr!a,yFran(e9is thec42nd -arge't co9ntcy in theeworld 6ut the 8arges^
# /ountryiibWez9eXneEuo  e jn0 the E!ropp   UcCo, 2 d 1hg shik -larg6st
# fb uuop $  ayuhoFX.  t a`pMban o& a$ rot  inga 7 fi lgoD,tit tY xjz
# a to coW Z ulltOd : unt5    dh h  cejoyd"mi t? o$uld    IuDPrt ;b0tg  U; F{an{  's b |ng a          esdN
# nsi   repullfcdwit; ita na" t{   n
#  riY thp"bax on'selargi ttoipt;    qh  qo"n I^ yu<al and coGmsrcha
# / ntOr  Tne o7preg     ttiyutkan 0f U m  e B  oltf     rY      r   n3 Ov   mu s

# %%
m4=[]
for m in range(len(cipher4)):
    m4.append(' ')
for i in range(len(k)):
    if(k[i]!='*'):
        m4[i] = chr(cipher4[i]^k[i])
for p in m4:
    print(p,end="")
# Out:
# The Moon (Latin: Luna) is theEarth ssonlyynaturallsatellite.
# AlthoughhnotttheelargesttnaturallsatelliteeinntheeSobarrSystemm ittisc
# amonggtheesatellitessoffmajorrplanett,,theelargesttrelativeetootheesize
# offtheeobjecttittorbitt (itssprimary)Aand,,afterrJuuiter's
# satelliteeIo,,ittisstheeseconddmosttdenseesatelliteeamobggthoseewhose
# densitiessareeknown.
#
# heeMoonnissinnsynchrEnoussrooationnwithhEarth,,alwayssshowinggtheesajeefaceewithhitssnearrsideemarkOddbyydarkkvvlcaniccmariaathattfilllbeeween
# theebrighttancienttcrustKllhighla'dbbanmmtBeeprr  neett mpacttcraa  s.-cttiss heemmss ll inoussobjjottii tee kyycftOO t  unn QQfoo hhitt ppp  s
# aa err  rggBttwhiiO,,kksscuufociYY ctxaFlyy arkk    hh   evllccaacc jj ttsll   lSShCChhrrxxaaee aa oo ww nnasshhlzz   ss      ennOOii     skyaadditssreggllrr yy   off haYY  htti,, inceeancii ttxiihh   aaeettkkMoEE lnnimportant
# cclttrrll nfFukncc obbnann     'caaenforss aa    nhh  ttoo     TT          rrbbtt   ff b

# %%
m5=[]
for m in range(len(cipher5)):
    m5.append(' ')
for i in range(len(cipher5)):
    if(k[i]!='*'):
        m5[i] = chr(cipher5[i]^k[i])

for p in m5:
    print(p,end="")
# Out:
# Courage
#
# Courage is the abiliRy and w:llin>ness tolconfront fear, paind da:geri
# uncert5inty, o> intimida1io . P-ysgca> coura&e i' c urage .n t-e face of
# #hy5ical "ain, hfrhshi5, deathx or thre$t  f d ath, wh/le (oral c;ur5ge
# is'the a1ility toAact ~ightl+ ik the face of pop0lar,op$os:tio+, sham!,
# sc5ndal,eor discou7ageae)t.
#
# I+ some tradition , f*rtitude -ol!s ap>ro+im/tely tBe sa>e veanin) as
# +ourage" In th6 Wester) tr$disin, n*tabl- th<ught! on &ouraMedha/e co&efrom p+iloso1herstsuchlas1Aristotl , Aqui:as and ierkeMa-rd; inity'
# een4liCmoo a/e < s w  n e9 loye  ly
# t<e dtYcersi=u hfpZcB ogt.

# %%
m6=[]
for m in range(len(cipher6)):
    m6.append(' ')
for i in range(len(cipher6)):
    if(k[i]!='*'):
        m6[i] = chr(cipher6[i]^k[i])
for p in m6:
    print(p,end="")
# Out:
# A university (Latin: "universOeas", "a whole") is an institutionaof
# higher education and,research which grants acajemic degr es in . variety
# of subjects and provides bot  undergraduate education and postgraduate
# education. The  ord "universit" is derived  rom the Latin universitas
# magistrorum et scholarium, which roukhly means "community of teachers andOscholars."
#
# The origCnal Latrn word "universitas" refers in general so "a number of
# persons associa^ed into one body, a society,  ompany, community, guild,
# corporation etc." A= ehe }imO of     e er ence of u   n yEwD li e an
#  ed  val guild   sp cil  ed  asY ci ins ov zu  nts a d    che   w t
# moFlecti O lg al0r gft uYu llt Muar nte        a tur   s u      pri    , prO a es  o e  e to ns  n wh c  z e  we      at N"  a   to bk  enominate
#  y  h    ene al
#   rm; @ik  other gu  ds   e    e e s b -rO  aating and
# dOt rm n d  he
# q{al fio vio      she r okmbirs

# %%
m7=[]
for m in range(len(cipher7)):
    m7.append(' ')
for i in range(len(k)):
    if(k[i]!='*'):
        m7[i] = chr(cipher7[i]^k[i])
for p in m0:
    print(p,end="")
# Out:
# Placement new operator:
#
# Line  cre tes an array of sizeof(Fred)abytes of memory, which es big
# enough to hold a Frkd object. Line 2ocreates a pointer place that points
# t  the first byte of this memory (experienced C programmers will note
# thatAthis step was unnecessary, it's there only to make the code more
# obvious . Lene 3 essentially just calls the cons1ructor Fred::Fred(). The thih pointer in the Fred constructor will bb  qual to place. The
# returned Zointer f wi l therefore be eq al to p ace.
#
# ADVICE: Don't use this Zlacementintw spntKx un   s  ou have to.     iy oDly  hen  o  r  lly care  dat  n b  ct ks Z ac  t   ` zi  lar
# l ca   n i  me o y  lor ex Gplg  wxe  wor Ba dwlrO ha  a      y  a pud I   i  r  evic    nN yE   anx t e  a e   C  ck o j cz a  th      or  lo a   n.
#
# JA GER: You  r  t k    sol  rO  onf nil ty that t   pci y    o  pa } to   h placement De  o e a  r Zognt  tc c r      hf  emm|y xha  e  be   n u              b     x g    n  b

# %%
#####try
print(m5)
for p in m5:
    print(p,end="")
# Out:
# ['C', 'o', 'u', 'r', 'a', 'g', 'e', '\n', '\n', 'C', 'o', 'u', 'r', 'a', 'g', 'e', ' ', 'i', 's', ' ', 't', 'h', 'e', ' ', 'a', 'b', 'i', 'l', 'i', 'R', 'y', ' ', 'a', 'n', 'd', ' ', 'w', ':', 'l', 'l', 'i', 'n', '>', 'n', 'e', 's', 's', ' ', 't', 'o', 'l', 'c', 'o', 'n', 'f', 'r', 'o', 'n', 't', ' ', 'f', 'e', 'a', 'r', ',', ' ', 'p', 'a', 'i', 'n', 'd', ' ', 'd', 'a', ':', 'g', 'e', 'r', 'i', '\n', 'u', 'n', 'c', 'e', 'r', 't', '5', 'i', 'n', 't', 'y', ',', ' ', 'o', '>', ' ', 'i', 'n', 't', 'i', 'm', 'i', 'd', 'a', '1', 'i', 'o', ' ', '.', ' ', 'P', '-', 'y', 's', 'g', 'c', 'a', '>', ' ', 'c', 'o', 'u', 'r', 'a', '&', 'e', ' ', 'i', "'", ' ', 'c', ' ', 'u', 'r', 'a', 'g', 'e', ' ', '.', 'n', ' ', 't', '-', 'e', ' ', 'f', 'a', 'c', 'e', ' ', 'o', 'f', '\n', '#', 'h', 'y', '5', 'i', 'c', 'a', 'l', ' ', '"', 'a', 'i', 'n', ',', ' ', 'h', 'f', 'r', 'h', 's', 'h', 'i', '5', ',', ' ', 'd', 'e', 'a', 't', 'h', 'x', ' ', 'o', 'r', ' ', 't', 'h', 'r', 'e', '$', 't', ' ', ' ', 'f', ' ', 'd'
# ...

# %%
m5_1 = ['C', 'o', 'u', 'r', 'a', 'g', 'e', '\n', '\n', 'C', 'o', 'u', 'r', 'a', 'g', 'e', ' ', 'i', 's', ' ', 't', 'h', 'e', ' ', 'a', 'b',
        'i', 'l', 'i', 't', 'y', ' ', 'a', 'n', 'd', ' ', 'w', 'i', 'l', 'l', 'i', 'n', 'g', 'n', 'e', 's', 's', ' ', 't', 'o', ' ', 'c', 'o'
        , 'n', 'f', 'r', 'o', 'n', 't', ' ', 'f', 'e', 'a', 'r', ',', ' ', 'p', 'a', 'i', 'n', ',', ' ', 'd', 'a', 'n', 'g', 'e', 'r', ',',
        '\n', 'u', 'n', 'c', 'e', 'r', 't', 'a', 'i', 'n', 't', 'y', ',', 'a', 'n', 'd', ' ', 'i', 'n', 't', 'i', 'm', 'i', 'd', 'a', 't',
        'i', 'o', 'n', '.', ' ', 'P', '-', 'y', 's', 'g', 'c', 'a', '>', ' ', 'c', 'o', 'u', 'r', 'a', '&', 'e', ' ', 'i', "'", ' ', 'c',
        ' ', 'u', 'r', 'a', 'g', 'e', ' ', '.', 'n', ' ', 't', '-', 'e', ' ', 'f', 'a', 'c', 'e', ' ', 'o', 'f', '\n', '#', 'h', 'y', '5', 
        'i', 'c', 'a', 'l', ' ', '"', 'a', 'i', 'n', ',', ' ', 'h', 'f', 'r', 'h', 's', 'h', 'i', '5', ',', ' ', 'd', 'e', 'a', 't', 'h',
        'x', ' ', 'o', 'r', ' ', 't', 'h', 'r', 'e', '$', 't', ' ', ' ', 'f', ' ', 'd', ' ', 'a', 't', 'h', ',', ' ', 'w', 'h', '/', 'l', 
        'e', ' ', '(', 'o', 'r', 'a', 'l', ' ', 'c', ';', 'u', 'r', '5', 'g', 'e', '\n', 'i', 's', "'", 't', 'h', 'e', ' ', 'a', '1', 'i',
        'l', 'i', 't', 'y', ' ', 't', 'o', 'A', 'a', 'c', 't', ' ', '~', 'i', 'g', 'h', 't', 'l', '+', ' ', 'i', 'k', ' ', 't', 'h', 'e',
        ' ', 'f', 'a', 'c', 'e', ' ', 'o', 'f', ' ', 'p', 'o', 'p', '0', 'l', 'a', 'r', ',', 'o', 'p', '$', 'o', 's', ':', 't', 'i', 'o',
        '+', ',', ' ', 's', 'h', 'a', 'm', '!', ',', '\n', 's', 'c', '5', 'n', 'd', 'a', 'l', ',', 'e', 'o', 'r', ' ', 'd', 'i', 's', 'c',
        'o', 'u', '7', 'a', 'g', 'e', 'a', 'e', ')', 't', '.', '\n', '\n', 'I', '+', ' ', 's', 'o', 'm', 'e', ' ', 't', 'r', 'a', 'd', 'i',
        't', 'i', 'o', 'n', ' ', ',', ' ', 'f', '*', 'r', 't', 'i', 't', 'u', 'd', 'e', ' ', '-', 'o', 'l', '!', 's', ' ', 'a', 'p', '>',
        'r', 'o', '+', 'i', 'm', '/', 't', 'e', 'l', 'y', ' ', 't', 'B', 'e', ' ', 's', 'a', '>', 'e', ' ', 'v', 'e', 'a', 'n', 'i', 'n',
        ')', ' ', 'a', 's', '\n', '+', 'o', 'u', 'r', 'a', 'g', 'e', '"', ' ', 'I', 'n', ' ', 't', 'h', '6', ' ', 'W', 'e', 's', 't', 'e',
        'r', ')', ' ', 't', 'r', '$', 'd', 'i', 's', 'i', '\x00', 'n', ',', ' ', 'n', '*', 't', 'a', 'b', 'l', '-', ' ', 't', 'h', '<',
        'u', 'g', 'h', 't', '!', ' ', 'o', 'n', ' ', '&', 'o', 'u', 'r', 'a', 'M', 'e', 'd', 'h', 'a', '/', 'e', ' ', 'c', 'o', '&', 'e',
        '\x13', 'f', 'r', 'o', 'm', ' ', 'p', '+', 'i', 'l', 'o', 's', 'o', '1', 'h', 'e', 'r', 's', 't', 's', 'u', 'c', 'h', 'l', 'a',
        's', '1', 'A', 'r', 'i', 's', 't', 'o', 't', 'l', ' ', ',', ' ', 'A', 'q', 'u', 'i', ':', 'a', 's', ' ', 'a', 'n', 'd', ' ',
        '\x1f', 'i', 'e', 'r', 'k', 'e', 'M', 'a', '-', 'r', 'd', ';', ' ', 'i', 'n', 'i', 't', 'y', "'", '\n', 'E', 'h', '>', 't', 'O',
        'r', '+', ' ', 't', 'o', ' ', ' ', 'i', 't', 'b', 'o', ':', ' ', ' ', 's', 'o', 'm', 'e', 't', 't', 'h', 'o', '`', ' ', ' ', 't',
        's', '-', 'E', 'n', '^', 'c', 'o', '&', ' ', 'a', 'g', ' ', ' ', 'u', 'e', 'u', 'e', ' ', 'v', ' ', 'f', 'e', 'r', 'e', 'd', 's',
        'b', 'y', ' ', '{', 'd', 'e', 't', 'T', 'f', 'o', ' ', ' ', 'e', 'O', ' ', 'h', 'i', '7', 'e', '.', ' ', 'g', 'R', 'r', 'e', 'W',
        '\x08', 'e', '\x10', 'e', 'n', '4', 'l', 'i', '\x11', 'C', 'm', 'o', 'o', ' ', 'a', '/', 'e', ' ', '<', ' ', 's', ' ', 'w', ' ', 
        ' ', 'n', ' ', 'e', '9', ' ', 'l', 'o', 'y', 'e', ' ', ' ', 'l', 'y', '\n', 't', '<', 'e', ' ', 'd', 't', 'Y', 'c', 'e', 'r',
        's', 'i', '=', 'u', ' ', 'h', 'f', '\x04', 'p', '\x15', 'Z', 'c', 'B', '\x16', ' ', 'o', 'g', 't', '.', ' ']

for i in range(len(cipher5)):
    k[i] = cipher5[i]^(ord(m5_1[i]))
print(k)
# Out:
# [187, 176, 204, 60, 6, 103, 83, 34, 209, 30, 76, 118, 195, 206, 222, 236, 18, 58, 242, 35, 117, 109, 24, 168, 236, 19, 249, 235, 24, 196, 34, 211, 116, 238, 16, 123, 85, 99, 157, 38, 129, 233, 156, 68, 183, 123, 48, 201, 181, 35, 236, 42, 144, 5, 210, 124, 24, 204, 103, 48, 144, 137, 4, 4, 120, 20, 127, 205, 119, 28, 244, 249, 6, 144, 61, 189, 11, 110, 135, 192, 145, 115, 235, 33, 120, 189, 158, 145, 137, 5, 193, 25, 206, 196, 8, 7, 217, 157, 212, 81, 186, 200, 74, 192, 89, 135, 125, 100, 245, 4, 37, 195, 120, 16, 166, 240, 205, 20, 129, 87, 75, 67, 112, 218, 73, 142, 225, 226, 120, 182, 51, 169, 126, 125, 166, 215, 4, 35, 123, 250, 40, 97, 197, 160, 113, 40, 144, 62, 110, 18, 149, 186, 85, 85, 148, 93, 210, 118, 63, 192, 44, 114, 244, 170, 239, 76, 130, 244, 112, 185, 238, 148, 31, 110, 56, 213, 151, 200, 206, 5, 218, 100, 191, 123, 106, 84, 141, 254, 202, 204, 191, 246, 122, 101, 160, 97, 178, 34, 34, 103, 224, 16, 186, 255, 127, 242, 143, 80, 186, 94, 27, 208, 194, 219, 196, 44, 4
# ...

# %%
m5_1 = ['T', 'h', 'e', ' ', 'M', 'o', 'o', 'n', ' ', '(', 'L', 'a', 't', 'i', 'n', ':', ' ', 'L', 'u', 'n', 'a', ')', ' ', 'i', 's', ' ',
        't', 'h', 'e', ' ', 'E', 'a', 'r', 't', 'h', ' ', 's', ' ', 'o', 'n', 'l', 'y', ' ', 'n', 'a', 't', 'u', 'r', 'a', 'l', ' ', 's',
        'a', 't', 'e', 'l', 'l', 'i', 't', 'e', '.', '\n', 'A', 'l', 't', 'h', 'o', 'u', 'g', 'h', ' ', 'n', 'o', 't', ' ', 't', 'h', 'e', 
        ' ', 'l', 'a', 'r', 'g', 'e', 's', 't', ' ', 'n', 'a', 't', 'u', 'r', 'a', 'l', ' ', 's', 'a', 't', 'e', 'l', 'l', 'i', 't', 'e',
        ' ', 'i', 'n', ' ', 't', 'h', 'e', ' ', 'S', 'o', 'b', 'a', 'r', ' ', 'S', 'y', 's', 't', 'e', 'm', ' ', ' ', 'i', 't', ' ', 'i', 
        's', 'c', '\n', 'a', 'm', 'o', 'n', 'g', ' ', 't', 'h', 'e', ' ', 's', 'a', 't', 'e', 'l', 'l', 'i', 't', 'e', 's', ' ', 'o', 'f',
        ' ', 'm', 'a', 'j', 'o', 'r', ' ', 'p', 'l', 'a', 'n', 'e', 't', ' ', ',', ' ', 't', 'h', 'e', ' ', 'l', 'a', 'r', 'g', 'e', 's',
        't', ' ', 'r', 'e', 'l', 'a', 't', 'i', 'v', 'e', ' ', 't', 'o', ' ', 't', 'h', 'e', ' ', 's', 'i', 'z', 'e', '\n', 'o', 'f', ' ', 
        't', 'h', 'e', ' ', 'o', 'b', 'j', 'e', 'c', 't', ' ', 'i', 't', ' ', 'o', 'r', 'b', 'i', 't', ' ', ' ', '(', 'i', 't', 's', ' ',
        'p', 'r', 'i', 'm', 'a', 'r', 'y', ')', 'A', 'a', 'n', 'd', ',', ' ', 'a', 'f', 't', 'e', 'r', ' ', 'J', 'u', ' ', 'i', 't', 'e',
        'r', "'", 's', '\n', 's', 'a', 't', 'e', 'l', 'l', 'i', 't', 'e', ' ', 'I', 'o', ',', ' ', 'i', 't', ' ', 'i', 's', ' ', 't', 'h',
        'e', ' ', 's', 'e', 'c', 'o', 'n', 'd', ' ', 'm', 'o', 's', 't', ' ', 'd', 'e', 'n', 's', 'e', ' ', 's', 'a', 't', 'e', 'l', 'l', 
        'i', 't', 'e', ' ', 'a', 'm', 'o', 'b', 'g', ' ', 't', 'h', 'o', 's', 'e', ' ', 'w', 'h', 'o', 's', 'e', '\n', 'd', 'e', 'n', 's',
        'i', 't', 'i', 'e', 's', ' ', 'a', 'r', 'e', ' ', 'k', 'n', 'o', 'w', 'n', '.', '\n', '\n', '\x11', 'h', 'e', ' ', 'M', 'o', 'o',
        'n', ' ', 'i', 's', ' ', 'i', 'n', ' ', 's', 'y', 'n', 'c', 'h', 'r', 'E', 'n', 'o', 'u', 's', ' ', 'r', 'o', 'o', 'a', 't', 'i',
        'o', 'n', ' ', 'w', 'i', 't', 'h', ' ', 'E', 'a', 'r', 't', 'h', ',', ' ', 'a', 'l', 'w', 'a', 'y', 's', ' ', 's', 'h', 'o', 'w',
        'i', 'n', 'g', ' ', 't', 'h', 'e', ' ', 's', 'a', 'j', 'e', ' ', 'f', 'a', 'c', 'e', ' ', 'w', 'i', 't', 'h', ' ', 'i', 't', 's', 
        ' ', 'n', 'e', 'a', 'r', ' ', 's', 'i', 'd', 'e', ' ', 'm', 'a', 'r', 'k', 'O', 'd', ' ', 'b', 'y', ' ', 'd', 'a', 'r', 'k', ' ', 
        'v', ' ', 'l', 'c', 'a', 'n', 'i', 'c', ' ', 'm', 'a', 'r', 'i', 'a', ' ', 't', 'h', 'a', 't', ' ', 'f', 'i', 'l', 'l', ' ', 'b', 
        'e', ' ', 'w', 'e', 'e', 'n', '\n', 't', 'h', 'e', ' ', 'b', 'r', 'i', 'g', 'h', 't', ' ', 'a', 'n', 'c', 'i', 'e', 'n', 't', ' ', 'c', 'r', 'u', 's', 't', 'K', 'l', ' ', 'h', 'i', 'g', 'h', 'l', 'a', "'", 'd', 'b', ' ', 'a', 'n', 'm', ' ', 't', 'B', 'e', ' ', 'p', 'r', ' ', ' ', ' ', 'n', 'e', ' ', 't', ' ', ' ', 'm', 'p', 'a', 'c', 't', ' ', 'c', 'r', 'a', ' ', ' ', ' ', 's', '.', '-', 'c', 't', ' ', 'i', 's', ' ', ' ', 'h', 'e', ' ', 'm', ' ', 's', ' ', ' ', 'l', ' ', ' ', 'i', 'n', 'o', 'u', 's', ' ', 'o', 'b', 'j', ' ', 'o', 't', ' ', 'i', ' ', ' ', 't', '\x1c', 'e', ' ', ' ', 'k', 'y', ' ', 'c', 'f', 't', 'O', ' ', ' ', 't', '\x1f', ' ', ' ', ' ', 'u', 'n', ' ', ' ', 'Q', ' ', '\x17', 'f', 'o', ' ', ' ', 'h', ' ', 'i', 't', ' ', ' ', 'p', 'p', ' ', ' ', ' ', 's', '\n', 'a', ' ', ' ', 'e', 'r', ' ', ' ', ' ', 'r', 'g', 'g', 'B', 't', ' ', 'w', 'h', 'i', ' ', 'O', ',', ' ', 'k', ' ', 's', ' ', 'c', 'u', ' ', 'f', 'o', 'c', '\x03', ' ', 'i', 'Y', ' ', ' ', 'c', 't', 'x', 'a', 'F', 'l', 'y', ' ', ' ', 'a', 'r', 'k', ' ', ' ', ' ', ' ', ' ', 'h', ' ', ' ', ' ', ' ', 'e', 'v', 'l', ' ', 'c', ' ', 'a', ' ', 'c', ' ', ' ', 'j', ' ', ' ', 't', ' ', 's', 'l', ' ', ' ', ' ', ' ', 'l', 'S', ' ', 'h', 'C', ' ', 'h', ' ', 'r', ' ', 'x', ' ', 'a', ' ', 'e', ' ', ' ', 'a', ' ', ' ', 'o', ' ', ' ', 'w', ' ', ' ', 'n', ' ', 'a', 's', ' ', 'h', ' ', 'l', 'z', ' ', ' ', ' ', ' ', 's', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'e', 'n', ' ', 'O', ' ', 'i', ' ', ' ', ' ', ' ', ' ', ' ', 's', 'k', 'y', '\x04', 'a', ' ', 'd', ' ', 'i', 't', 's', ' ', 'r', 'e', 'g', ' ', 'l', ' ', 'r', ' ', ' ', 'y', ' ', ' ', ' ', ' ', 'o', 'f', ' ', ' ', 'h', 'a', 'Y', ' ', ' ', ' ', 'h', 't', ' ', 'i', ',', ' ', ' ', 'i', 'n', 'c', 'e', ' ', 'a', 'n', 'c', 'i', ' ', ' ', 't', ' ', 'x', 'i', ' ', 'h', ' ', ' ', ' ', ' ', 'a', ' ', 'e', ' ', 't', ' ', 'k', ' ', 'M', 'o', 'E', ' ', ' ', 'l', 'n', ' ', 'i', 'm', 'p', 'o', 'r', 't', 'a', 'n', 't', '\n', 'c', ' ', 'l', 't', ' ', 'r', ' ', 'l', ' ', ' ', 'n', 'f', 'F', 'u', 'k', 'n', 'c', ' ', ' ', 'o', 'b', ' ', 'n', 'a', 'n', ' ', ' ', ' ', ' ', ' ', ' ', "'", 'c', 'a', ' ', 'e', 'n', 'f', 'o', 'r', 's', ' ', ' ', 'a', ' ', ' ', ' ', ' ', ' ', 'n', 'h', ' ', ' ', ' ', 't', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', 'T', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'r', ' ', 'b', ' ', 't', ' ', ' ', ' ', ' ', 'f', ' ', ' ', 'b', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

for i in range(len(cipher4)):
    if m4_1[i]!=' ':
        k[i] = cipher4[i]^(ord(m4_1[i]))
print(k)
# Out:
# [187, 176, 204, 60, 6, 103, 83, 34, 209, 30, 76, 118, 195, 206, 222, 236, 18, 58, 242, 35, 117, 109, 24, 168, 236, 19, 249, 235, 24, 226, 34, 211, 116, 238, 16, '*', 85, 48, 157, 38, 129, 233, 197, 68, 183, 123, 48, 201, 181, 35, 160, 42, 144, 5, 210, 124, 24, 204, 103, 48, 144, 137, 4, 4, 120, 20, 127, 205, 119, 28, 188, 249, 6, 144, 105, 189, 11, 110, 194, 192, 145, 115, 235, 33, 120, 189, 202, 145, 137, 5, 193, 25, 143, 197, 82, 7, 217, 157, 212, 81, 186, 200, 74, 192, 28, 135, 125, 42, 245, 4, 37, 195, 120, 16, 166, 240, 205, 20, 129, 87, 75, 67, 112, 218, 73, 142, 225, 226, 120, 182, 51, 169, 126, 125, 166, 215, 4, 35, 123, 250, 40, 97, 197, 160, 113, 40, 144, 62, 110, 18, 149, 186, 85, 85, 148, 93, 210, 118, 63, 192, 44, 114, 244, 170, 239, 76, 130, 244, 112, 185, 238, 148, 31, 110, 56, 213, 151, 200, 206, 5, 218, 100, 191, 123, 106, 84, 141, 254, 202, 204, 191, 246, 122, 101, 160, 97, 178, 34, 34, 103, 224, 16, 186, 255, 127, 242, 143, 80, 186, 94, 27, 208, 194, 219, 196, 44, 
# ...
